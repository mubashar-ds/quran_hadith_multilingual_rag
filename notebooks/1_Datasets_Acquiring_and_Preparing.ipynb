# %% [markdown]
# #**1 - Quran Datasets Download**

# %%
import requests
from pathlib import Path

def download_file(url: str, save_path: Path) -> bool:

    try:
        response = requests.get(url, timeout=20)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f'Could not download {url}\nReason: {e}')
        return False

    save_path.parent.mkdir(parents=True, exist_ok=True)

    save_path.write_text(response.text, encoding="utf-8")

    print(f"[OK] Saved: {save_path}")
    return True

# Quran dataset list..
datasets = {
    "Quran_ar.json": "https://cdn.jsdelivr.net/npm/quran-json@3.1.2/dist/quran.json",
    "Quran_ur.json": "https://cdn.jsdelivr.net/npm/quran-json@3.1.2/dist/quran_ur.json",
    "Quran_en.json": "https://cdn.jsdelivr.net/npm/quran-json@3.1.2/dist/quran_en.json",
}

# base directory in Google Colab..
DATA_DIR = Path("/content/Quran_datasets")

print("Downloading the Quran Datasets (Arabic / Urdu / English)\n")

for filename, url in datasets.items():
    save_path = DATA_DIR / filename
    download_file(url, save_path)

print("\nAll Quran datasets downloaded successfully!")
print(f"\nFiles are stored in: {DATA_DIR.resolve()}")
# Out:
# Downloading the Quran Datasets (Arabic / Urdu / English)
#
# [OK] Saved: /content/Quran_datasets/Quran_ar.json
# [OK] Saved: /content/Quran_datasets/Quran_ur.json
# [OK] Saved: /content/Quran_datasets/Quran_en.json
#
# All Quran datasets downloaded successfully!
#
# Files are stored in: /content/Quran_datasets

# %% [markdown]
# **1.1 - Quran Datasets Merge**

# %%
import json
from pathlib import Path

DATA_DIR = Path("/content/Quran_datasets")

with open(DATA_DIR / "Quran_ar.json", "r", encoding="utf-8") as f:
    quran_ar = json.load(f)

with open(DATA_DIR / "Quran_ur.json", "r", encoding="utf-8") as f:
    quran_ur = json.load(f)

with open(DATA_DIR / "Quran_en.json", "r", encoding="utf-8") as f:
    quran_en = json.load(f)

print("Datasets loaded successfully!")

merged_quran = []
global_quran_id = 1

for surah_ar, surah_en, surah_ur in zip(quran_ar, quran_en, quran_ur):

    surah_id = surah_ar["id"]
    surah_name_ar = surah_ar["name"]
    surah_name_en = surah_en["translation"]
    surah_name_ur = surah_ur["translation"]

    transliteration = surah_ar["transliteration"]
    surah_type = surah_ar["type"]

    for v_ar, v_en, v_ur in zip(surah_ar["verses"], surah_en["verses"], surah_ur["verses"]):

        ayah_id = v_ar["id"]

        doc = {
            "doc_id": f"Q_{surah_id}_{ayah_id}",
            "quran_id": global_quran_id,
            "surah_id": surah_id,
            "ayah_id": ayah_id,
            "source": "Quran",

            "surah_name_ar": surah_name_ar,
            "surah_name_en": surah_name_en,
            "surah_name_ur": surah_name_ur,

            "transliteration": transliteration,
            "surah_type": surah_type,

            "text_ar": v_ar["text"],
            "text_en": v_en["translation"],
            "text_ur": v_ur["translation"]
        }

        merged_quran.append(doc)
        global_quran_id += 1

OUTPUT_PATH = Path("/content/1_Quran_merged.json")
OUTPUT_PATH.write_text(json.dumps(merged_quran, ensure_ascii=False, indent=2), encoding="utf-8")

print(f"\nMerged Quran dataset created!\n\nSaved at: {OUTPUT_PATH}")
print(f"\nTotal verses merged: {len(merged_quran)}")
# Out:
# Datasets loaded successfully!
#
# Merged Quran dataset created!
#
# Saved at: /content/Quran_merged.json
#
# Total verses merged: 6236

# %% [markdown]
# **1.2 - Juz in Quran Dataset**

# %%
import json
from pathlib import Path

MERGED_PATH = Path("/content/1_Quran_merged.json")

with open(MERGED_PATH, "r", encoding="utf-8") as f:
    merged_quran = json.load(f)

print(f"Merged Quran records loaded: {len(merged_quran)}")

# Juz boundaries..
juz_boundaries = [
    {"juz": 1,  "start": (1, 1),   "end": (2, 141)},
    {"juz": 2,  "start": (2, 142), "end": (2, 252)},
    {"juz": 3,  "start": (2, 253), "end": (3, 91)},
    {"juz": 4,  "start": (3, 92),  "end": (4, 23)},
    {"juz": 5,  "start": (4, 24),  "end": (4, 147)},
    {"juz": 6,  "start": (4, 148), "end": (5, 82)},
    {"juz": 7,  "start": (5, 83),  "end": (6, 110)},
    {"juz": 8,  "start": (6, 111), "end": (7, 87)},
    {"juz": 9,  "start": (7, 88),  "end": (8, 40)},
    {"juz": 10, "start": (8, 41),  "end": (9, 93)},
    {"juz": 11, "start": (9, 94),  "end": (11, 5)},
    {"juz": 12, "start": (11, 6),  "end": (12, 52)},
    {"juz": 13, "start": (12, 53), "end": (15, 1)},
    {"juz": 14, "start": (15, 2),  "end": (16, 128)},
    {"juz": 15, "start": (17, 1),  "end": (18, 74)},
    {"juz": 16, "start": (18, 75), "end": (20, 135)},
    {"juz": 17, "start": (21, 1),  "end": (22, 78)},
    {"juz": 18, "start": (23, 1),  "end": (25, 20)},
    {"juz": 19, "start": (25, 21), "end": (27, 59)},
    {"juz": 20, "start": (27, 60), "end": (29, 44)},
    {"juz": 21, "start": (29, 45), "end": (33, 30)},
    {"juz": 22, "start": (33, 31), "end": (36, 21)},
    {"juz": 23, "start": (36, 22), "end": (39, 31)},
    {"juz": 24, "start": (39, 32), "end": (41, 46)},
    {"juz": 25, "start": (41, 47), "end": (45, 37)},
    {"juz": 26, "start": (46, 1),  "end": (51, 30)},
    {"juz": 27, "start": (51, 31), "end": (57, 29)},
    {"juz": 28, "start": (58, 1),  "end": (66, 12)},
    {"juz": 29, "start": (67, 1),  "end": (77, 50)},
    {"juz": 30, "start": (78, 1),  "end": (114, 6)},
]

def is_in_range(surah, ayah, start, end):

    s_surah, s_ayah = start
    e_surah, e_ayah = end

    if surah < s_surah or surah > e_surah:
        return False

    if surah == s_surah and ayah < s_ayah:
        return False

    if surah == e_surah and ayah > e_ayah:
        return False

    return True

# assigning the Juz numbers..
for doc in merged_quran:
    surah = doc["surah_id"]
    ayah = doc["ayah_id"]

    # assign juz by range lookup...
    for item in juz_boundaries:
        if is_in_range(surah, ayah, item["start"], item["end"]):
            doc["juz"] = item["juz"]
            break

OUTPUT_PATH = Path("/content/1_Quran_merged_juz.json")

OUTPUT_PATH.write_text(
    json.dumps(merged_quran, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print("\nJuz added successfully!")
print(f"\nSaved updated file to: {OUTPUT_PATH}")
# Out:
# Merged Quran records loaded: 6236
#
# Juz added successfully!
#
# Saved updated file to: /content/Quran_merged_juz.json

# %% [markdown]
# **1.3 - Quran Dataset Analysis**

# %%
import json
import re
from pathlib import Path

DATA_PATH = Path("/content/1_Quran_merged_juz.json")
quran = json.loads(DATA_PATH.read_text(encoding="utf-8"))

print(f"Loaded {len(quran)} ayahs.\n")

checks = {
    "required_fields": True,
    "doc_id_format": True,
    "arabic_text": True,
    "english_translation": True,
    "urdu_translation": True,
    "quran_id_order": True,
    "surah_range": True,
    "juz_range": True
}

required_fields = [
    "doc_id","quran_id","surah_id","ayah_id",
    "surah_name_ar","surah_name_en","surah_name_ur",
    "transliteration","surah_type",
    "text_ar","text_en","text_ur",
    "juz"
]

# 1 - required fields ...
for d in quran:
    for k in required_fields:
        if k not in d or d[k] in ["", None]:
            checks["required_fields"] = False

# 2 - doc_id format..
pat = re.compile(r"^Q_\d+_\d+$")
for d in quran:
    if not pat.match(d["doc_id"]):
        checks["doc_id_format"] = False

# 3 - arabic text contains Arabic
for d in quran:
    if not re.search(r"[\u0600-\u06FF]", d["text_ar"]):
        checks["arabic_text"] = False

# 4 - english translation is non-empty and string..
for d in quran:
    if not isinstance(d["text_en"], str) or d["text_en"].strip() == "":
        checks["english_translation"] = False

# 5 - urdu translation is non-empty and string...
for d in quran:
    if not isinstance(d["text_ur"], str) or d["text_ur"].strip() == "":
        checks["urdu_translation"] = False

# 6 - quran_id in order
for i, d in enumerate(quran, start=1):
    if d["quran_id"] != i:
        checks["quran_id_order"] = False

# 7 - surah_id valid
for d in quran:
    if not (1 <= d["surah_id"] <= 114):
        checks["surah_range"] = False

# 8 - juz valid
for d in quran:
    if not (1 <= d["juz"] <= 30):
        checks["juz_range"] = False

print("Required Fields Check:", "PASS" if checks["required_fields"] else "FAIL")
print("\ndoc_id Format Check:", "PASS" if checks["doc_id_format"] else "FAIL")

print("\nArabic Text Check:", "PASS" if checks["arabic_text"] else "FAIL")
print("Urdu Translation Check:", "PASS" if checks["urdu_translation"] else "FAIL")
print("English Translation Check:", "PASS" if checks["english_translation"] else "FAIL")

print("\nquran_id Order Check:", "PASS" if checks["quran_id_order"] else "FAIL")
print("Surah Range Check:", "PASS" if checks["surah_range"] else "FAIL")
print("Juz Range Check:", "PASS" if checks["juz_range"] else "FAIL")
# Out:
# Loaded 6236 ayahs.
#
# Required Fields Check: PASS
#
# doc_id Format Check: PASS
#
# Arabic Text Check: PASS
# Urdu Translation Check: PASS
# English Translation Check: PASS
#
# quran_id Order Check: PASS
# Surah Range Check: PASS
# Juz Range Check: PASS

# %%
import json
import pandas as pd
import numpy as np
import os

file_path = '/content/1_Quran_merged_juz.json'

if not os.path.exists(file_path):
    print(f"ERROR: File not found at: {file_path}\n")
    print("Please check the path and try again.")
else:
    print(f"Scanning {file_path}...")

    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    df = pd.DataFrame(data)

    # ensuring that quran_id is integer..
    # Using errors = 'coerce' turns non-numeric values into NaN..
    df['quran_id'] = pd.to_numeric(df['quran_id'], errors='coerce')

    print(f"\nVALIDATION REPORT FOR 'quran_id")

    # 1 - checking for duplicates..
    duplicates = df[df.duplicated('quran_id', keep=False)]
    if not duplicates.empty:
        print(f"FAILED: Found {len(duplicates.drop_duplicates(subset=['quran_id']))} duplicate Quran IDs.")
        print("Duplicate IDs:", duplicates['quran_id'].unique().tolist()[:20], "...")
    else:
        print("\nDuplicates: None")

    # 2 - checking for the missing Numbers (gaps in sequence)...
    # filtering out any rows where quran_id is invalid/NaN
    valid_ids = df['quran_id'].dropna().astype(int)

    if valid_ids.empty:
         print("FAILED: 'quran_id' column is empty or invalid.")
    else:
        max_id = int(valid_ids.max())
        expected_ids = set(range(1, max_id + 1))
        actual_ids = set(valid_ids)

        missing_ids = sorted(list(expected_ids - actual_ids))

        if missing_ids:
            print(f"FAILED: Sequence is broken. Found {len(missing_ids)} missing IDs.")
            print(f"First 10 missing IDs: {missing_ids[:10]}")
        else:
            print("Sequence: Perfect (1 to Last)")

        # 3 - checking Start
        min_id = int(valid_ids.min())
        if min_id != 1:
            print(f"WARNING: Sequence starts at {min_id}, not 1.")
        else:
            print("Start: Sequence starts at 1.")

        # 4 - total Count Check..
        print(f"\nSUMMARY")
        print(f"\nTotal Rows: {len(df)}")
        print(f"Max Quran ID found: {max_id}")

        if len(duplicates) == 0 and len(missing_ids) == 0 and min_id == 1:
            print("\nRESULT: PERFECT SEQUENCE. 'quran_id' is clean.")
        else:
            print("\nRESULT: DATASET HAS ERRORS. Fix duplicates/missing IDs before using.")
# Out:
# Scanning /content/Quran_merged_juz.json...
#
# VALIDATION REPORT FOR 'quran_id
#
# Duplicates: None
# Sequence: Perfect (1 to Last)
# Start: Sequence starts at 1.
#
# SUMMARY
#
# Total Rows: 6236
# Max Quran ID found: 6236
#
# RESULT: PERFECT SEQUENCE. 'quran_id' is clean.

# %% [markdown]
# #**2 - Hadith Dataset from Hadith API**

# %%
import requests
import json
import time
import sys

API_KEY = "$2y$10$bxpfV3LpNWhUKJvdVcOqe9dLd4jeM2x55z9gegNcONYekiI4maS"
BASE_URL = "https://hadithapi.com/api/hadiths"
BOOK_SLUG = "sahih-bukhari"
OUTPUT_FILE = "1_Sahih_Bukhari_HadithAPI.json"

PER_PAGE = 50
BASE_DELAY = 1.5
MAX_RETRIES = 3

all_hadith = []
page = 1

print(f"Starting Download for {BOOK_SLUG}\n")

try:
    while True:
        url = f"{BASE_URL}?book={BOOK_SLUG}&paginate={PER_PAGE}&page={page}&apiKey={API_KEY}"

        success = False
        for attempt in range(MAX_RETRIES):
            try:
                print(f"Fetching page {page} (Attempt {attempt + 1})...", end=" ")
                resp = requests.get(url, timeout=10)

                if resp.status_code == 429:
                    print("\nToo Many Requests! Cooling down for 30 seconds...")
                    time.sleep(30)
                    continue

                if resp.status_code != 200:
                    print(f"Error: {resp.status_code}")
                    time.sleep(5)
                    continue

                data = resp.json()
                hadith_list = data.get("hadiths", {}).get("data", [])

                if not hadith_list:
                    print("\nNo more data found. Download complete!")
                    success = True
                    break

                for h in hadith_list:
                    formatted = {
                        "doc_id": f"H_Bukhari_{h.get('hadithNumber', 'Unknown')}",
                        "source": "Hadith",
                        "book": "Sahih Bukhari",
                        "book_id": h.get("book", {}).get("id"),
                        "chapter_id": h.get("chapter", {}).get("id"),
                        "hadith_id": h.get("hadithNumber"),
                        "bukhari_id": h.get("id"),

                        "chapter_name_ar": h.get("chapter", {}).get("chapterArabic"),
                        "chapter_name_en": h.get("chapter", {}).get("chapterEnglish"),
                        "chapter_name_ur": h.get("chapter", {}).get("chapterUrdu"),

                        "arabic_text": h.get("hadithArabic"),
                        "english_text": h.get("hadithEnglish"),
                        "urdu_text": h.get("hadithUrdu"),

                        "narrator": h.get("englishNarrator"),
                        "status": h.get("status", "Sahih"),
                        "tags": []
                    }
                    all_hadith.append(formatted)

                print(f"Done. (Total: {len(all_hadith)})")
                success = True

                last_page = data.get("hadiths", {}).get("last_page")
                if last_page and page >= last_page:
                    print("Reached the last page defined by API.")
                    sys.exit(0)

                break

            except requests.exceptions.RequestException as e:
                print(f"\nNetwork Error: {e}. Retrying in 5s")
                time.sleep(5)

        if not success and not hadith_list:
            break
        elif not success:
            print(f"\nFailed to fetch page {page} after {MAX_RETRIES} attempts. Stopping safely.")
            break

        page += 1
        time.sleep(BASE_DELAY)

except KeyboardInterrupt:
    print("\nScript stopped manually by user.")

except SystemExit:
    pass

finally:
    print(f"\nSaving {len(all_hadith)} Hadiths to file.")
    if len(all_hadith) > 0:
        with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
            json.dump(all_hadith, f, ensure_ascii=False, indent=2)
        print(f"\nSuccessfully saved to {OUTPUT_FILE}")
    else:
        print("No data collected to save.")
# Out:
# Starting Download for sahih-bukhari
#
# Fetching page 1 (Attempt 1)... Done. (Total: 50)
# Fetching page 2 (Attempt 1)... Done. (Total: 100)
# Fetching page 3 (Attempt 1)... Done. (Total: 150)
# Fetching page 4 (Attempt 1)... Done. (Total: 200)
# Fetching page 5 (Attempt 1)... Done. (Total: 250)
# Fetching page 6 (Attempt 1)... Done. (Total: 300)
# Fetching page 7 (Attempt 1)... Done. (Total: 350)
# Fetching page 8 (Attempt 1)... Done. (Total: 400)
# Fetching page 9 (Attempt 1)... Done. (Total: 450)
# Fetching page 10 (Attempt 1)... Done. (Total: 500)
# Fetching page 11 (Attempt 1)... Done. (Total: 550)
# Fetching page 12 (Attempt 1)... Done. (Total: 600)
# Fetching page 13 (Attempt 1)... Done. (Total: 650)
# Fetching page 14 (Attempt 1)... Done. (Total: 700)
# Fetching page 15 (Attempt 1)... Done. (Total: 750)
# Fetching page 16 (Attempt 1)... Done. (Total: 800)
# Fetching page 17 (Attempt 1)... Done. (Total: 850)
# Fetching page 18 (Attempt 1)... Done. (Total: 900)
# Fetching page 19 (Attempt 1)... Done. (Total: 950)
# Fetching page 20 (Attempt 1)... Done. (Total: 1000)
# Fetching page 21 (Attempt 1)... Done. (Total: 1050)
# Fetching page 22 (Attempt 1)... Done. (Total: 1100)
# Fetching page 23 (Attempt 1)... Done. (Total: 1150)
# Fetching page 24 (Attempt 1)... Done. (Total: 1200)
# Fetching page 25 (Attempt 1)... Done. (Total: 1250)
# Fetching page 26 (Attempt 1)... Done. (Total: 1300)
# Fetching page 27 (Attempt 1)... Done. (Total: 1350)
# Fetching page 28 (Attempt 1)... Done. (Total: 1400)
# Fetching page 29 (Attempt 1)... Done. (Total: 1450)
# Fetching page 30 (Attempt 1)... Done. (Total: 1500)
# Fetching page 31 (Attempt 1)... Done. (Total: 1550)
# Fetching page 32 (Attempt 1)... Done. (Total: 1600)
# Fetching page 33 (Attempt 1)... Done. (Total: 1650)
# Fetching page 34 (Attempt 1)... Done. (Total: 1700)
# Fetching page 35 (Attempt 1)... Done. (Total: 1750)
# Fetching page 36 (Attempt 1)... Done. (Total: 1800)
# Fetching page 37 (Attempt 1)... Done. (Total: 1850)
# Fetching page 38 (Attempt 1)... Done. (Total: 1900)
# Fetching page 39 (Attempt 1)... Done. (Total: 1950)
# Fetching page 40 (Attempt 1)... Done. (Total: 2000)
# Fetching page 41 (Attempt 1)... Done. (Total: 2050)
# Fetching page 42 (Attempt 1)... Done. (Total: 2100)
# Fetching page 43 (Attempt 1)... Done. (Total: 2150)
# Fetching page 44 (Attempt 1)... Done. (Total: 2200)
# Fetching page 45 (Attempt 1)... Done. (Total: 2250)
# Fetching page 46 (Attempt 1)... Done. (Total: 2300)
# Fetching page 47 (Attempt 1)... Done. (Total: 2350)
# Fetching page 48 (Attempt 1)... Done. (Total: 2400)
# Fetching page 49 (Attempt 1)... Done. (Total: 2450)
# Fetching page 50 (Attempt 1)... Done. (Total: 2500)
# Fetching page 51 (Attempt 1)... Done. (Total: 2550)
# Fetching page 52 (Attempt 1)... Done. (Total: 2600)
# Fetching page 53 (Attempt 1)... Done. (Total: 2650)
# Fetching page 54 (Attempt 1)... Done. (Total: 2700)
# Fetching page 55 (Attempt 1)... Done. (Total: 2750)
# Fetching page 56 (Attempt 1)... Done. (Total: 2800)
# Fetching page 57 (Attempt 1)... Done. (Total: 2850)
# Fetching page 58 (Attempt 1)... Done. (Total: 2900)
# Fetching page 59 (Attempt 1)... Done. (Total: 2950)
# Fetching page 60 (Attempt 1)... Done. (Total: 3000)
# Fetching page 61 (Attempt 1)... Done. (Total: 3050)
# Fetching page 62 (Attempt 1)... Done. (Total: 3100)
# Fetching page 63 (Attempt 1)... Done. (Total: 3150)
# Fetching page 64 (Attempt 1)... Done. (Total: 3200)
# Fetching page 65 (Attempt 1)... Done. (Total: 3250)
# Fetching page 66 (Attempt 1)... Done. (Total: 3300)
# Fetching page 67 (Attempt 1)... Done. (Total: 3350)
# Fetching page 68 (Attempt 1)... Done. (Total: 3400)
# Fetching page 69 (Attempt 1)... Done. (Total: 3450)
# Fetching page 70 (Attempt 1)... Done. (Total: 3500)
# Fetching page 71 (Attempt 1)... Done. (Total: 3550)
# Fetching page 72 (Attempt 1)... Done. (Total: 3600)
# Fetching page 73 (Attempt 1)... Done. (Total: 3650)
# Fetching page 74 (Attempt 1)... Done. (Total: 3700)
# Fetching page 75 (Attempt 1)... Done. (Total: 3750)
# Fetching page 76 (Attempt 1)... Done. (Total: 3800)
# Fetching page 77 (Attempt 1)... Done. (Total: 3850)
# Fetching page 78 (Attempt 1)... Done. (Total: 3900)
# Fetching page 79 (Attempt 1)... Done. (Total: 3950)
# Fetching page 80 (Attempt 1)... Done. (Total: 4000)
# Fetching page 81 (Attempt 1)... Done. (Total: 4050)
# Fetching page 82 (Attempt 1)... Done. (Total: 4100)
# Fetching page 83 (Attempt 1)... Done. (Total: 4150)
# Fetching page 84 (Attempt 1)... Done. (Total: 4200)
# Fetching page 85 (Attempt 1)... Done. (Total: 4250)
# Fetching page 86 (Attempt 1)... Done. (Total: 4300)
# Fetching page 87 (Attempt 1)... Done. (Total: 4350)
# Fetching page 88 (Attempt 1)... Done. (Total: 4400)
# Fetching page 89 (Attempt 1)... Done. (Total: 4450)
# Fetching page 90 (Attempt 1)... Done. (Total: 4500)
# Fetching page 91 (Attempt 1)... Done. (Total: 4550)
# Fetching page 92 (Attempt 1)... Done. (Total: 4600)
# Fetching page 93 (Attempt 1)... Done. (Total: 4650)
# Fetching page 94 (Attempt 1)... Done. (Total: 4700)
# Fetching page 95 (Attempt 1)... Done. (Total: 4750)
# Fetching page 96 (Attempt 1)... Done. (Total: 4800)
# Fetching page 97 (Attempt 1)... Done. (Total: 4850)
# Fetching page 98 (Attempt 1)... Done. (Total: 4900)
# Fetching page 99 (Attempt 1)... Done. (Total: 4950)
# Fetching page 100 (Attempt 1)... Done. (Total: 5000)
# Fetching page 101 (Attempt 1)... Done. (Total: 5050)
# Fetching page 102 (Attempt 1)... Done. (Total: 5100)
# Fetching page 103 (Attempt 1)... Done. (Total: 5150)
# Fetching page 104 (Attempt 1)... Done. (Total: 5200)
# Fetching page 105 (Attempt 1)... Done. (Total: 5250)
# Fetching page 106 (Attempt 1)... Done. (Total: 5300)
# Fetching page 107 (Attempt 1)... Done. (Total: 5350)
# Fetching page 108 (Attempt 1)... Done. (Total: 5400)
# Fetching page 109 (Attempt 1)... Done. (Total: 5450)
# Fetching page 110 (Attempt 1)... Done. (Total: 5500)
# Fetching page 111 (Attempt 1)... Done. (Total: 5550)
# Fetching page 112 (Attempt 1)... Done. (Total: 5600)
# Fetching page 113 (Attempt 1)... Done. (Total: 5650)
# Fetching page 114 (Attempt 1)... Done. (Total: 5700)
# Fetching page 115 (Attempt 1)... Done. (Total: 5750)
# Fetching page 116 (Attempt 1)... Done. (Total: 5800)
# Fetching page 117 (Attempt 1)... Done. (Total: 5850)
# Fetching page 118 (Attempt 1)... Done. (Total: 5900)
# Fetching page 119 (Attempt 1)... Done. (Total: 5950)
# Fetching page 120 (Attempt 1)... Done. (Total: 6000)
# Fetching page 121 (Attempt 1)... Done. (Total: 6050)
# Fetching page 122 (Attempt 1)... Done. (Total: 6100)
# Fetching page 123 (Attempt 1)... Done. (Total: 6150)
# Fetching page 124 (Attempt 1)... Done. (Total: 6200)
# Fetching page 125 (Attempt 1)... Done. (Total: 6250)
# Fetching page 126 (Attempt 1)... Done. (Total: 6300)
# Fetching page 127 (Attempt 1)... Done. (Total: 6350)
# Fetching page 128 (Attempt 1)... Done. (Total: 6400)
# Fetching page 129 (Attempt 1)... Done. (Total: 6450)
# Fetching page 130 (Attempt 1)... Done. (Total: 6500)
# Fetching page 131 (Attempt 1)... Done. (Total: 6550)
# Fetching page 132 (Attempt 1)... Done. (Total: 6600)
# Fetching page 133 (Attempt 1)... Done. (Total: 6650)
# Fetching page 134 (Attempt 1)... Done. (Total: 6700)
# Fetching page 135 (Attempt 1)... Done. (Total: 6750)
# Fetching page 136 (Attempt 1)... Done. (Total: 6800)
# Fetching page 137 (Attempt 1)... Done. (Total: 6850)
# Fetching page 138 (Attempt 1)... Done. (Total: 6900)
# Fetching page 139 (Attempt 1)... Done. (Total: 6950)
# Fetching page 140 (Attempt 1)... Done. (Total: 7000)
# Fetching page 141 (Attempt 1)... Done. (Total: 7050)
# Fetching page 142 (Attempt 1)... Done. (Total: 7100)
# Fetching page 143 (Attempt 1)... Done. (Total: 7150)
# Fetching page 144 (Attempt 1)... Done. (Total: 7200)
# Fetching page 145 (Attempt 1)... Done. (Total: 7250)
# Fetching page 146 (Attempt 1)... Done. (Total: 7276)
# Reached the last page defined by API.
#
# Saving 7276 Hadiths to file.
#
# Successfully saved to Sahih_Bukhari_HadithAPI.json

# %% [markdown]
# **2.1 - Hadith Dataset Sorting**

# %%
import json
import re

input_filename = "/content/1_Sahih_Bukhari_HadithAPI.json"
output_filename = "2_Sahih_Bukhari_sorted.json"

print("Loading file...")
with open(input_filename, "r", encoding="utf-8") as f:
    data = json.load(f)

def get_sort_key(item):

    h_id = str(item.get("hadith_id", "0"))

    numbers = re.findall(r'\d+', h_id)

    if numbers:
        return int(numbers[0])
    return 0

print("\nSorting hadiths...")
sorted_data = sorted(data, key = get_sort_key)

print(f"\nSaving to {output_filename}...")
with open(output_filename, "w", encoding="utf-8") as f:
    json.dump(sorted_data, f, ensure_ascii=False, indent=2)

print("\nDone! Your file is now perfectly sorted.")
# Out:
# Loading file...
#
# Sorting hadiths...
#
# Saving to Sahih_Bukhari_sorted.json...
#
# Done! Your file is now perfectly sorted.

# %% [markdown]
# **2.2 - Hadith Dataset Analysis**

# %%
import pandas as pd

FILE_PATH = "/content/2_Sahih_Bukhari_sorted.json"

if FILE_PATH.endswith(".json"):
    df = pd.read_json(FILE_PATH)
elif FILE_PATH.endswith(".csv"):
    df = pd.read_csv(FILE_PATH)
elif FILE_PATH.endswith(".ndjson"):
    df = pd.read_json(FILE_PATH, lines=True)
else:
    raise ValueError("Unsupported file format")

chapters = (
    df[["chapter_id", "chapter_name_ar", "chapter_name_en", "chapter_name_ur"]]
    .drop_duplicates()
    .sort_values("chapter_id")
    .reset_index(drop=True)
)

print("Beautiful Chapter Listing (Your Dataset)")

for _, row in chapters.iterrows():
    print(f"\nChapter ---> {row['chapter_id']}")
    print(f"Arabic   :   {row['chapter_name_ar']}")
    print(f"Urdu   :   {row['chapter_name_ur']}")
    print(f"English   :   {row['chapter_name_en']}")

print(f"\nTotal Chapters Found: {len(chapters)}")
# Out:
# Beautiful Chapter Listing (Your Dataset)
#
# Chapter ---> 1
# Arabic   :   كتاب بدء الوحى
# Urdu   :   وحی کے بیان میں
# English   :   Revelation
#
# Chapter ---> 2
# Arabic   :   كتاب الإيمان
# Urdu   :   ایمان کے بیان میں
# English   :   Belief
#
# Chapter ---> 3
# Arabic   :   كتاب العلم
# Urdu   :   علم کے بیان میں
# English   :   Knowledge
#
# Chapter ---> 4
# Arabic   :   كتاب الوضوء
# Urdu   :   وضو کے بیان میں
# English   :   Ablutions (Wudu')
#
# Chapter ---> 5
# Arabic   :   كتاب الغسل
# Urdu   :   غسل کے احکام و مسائل
# English   :   Bathing (Ghusl)
#
# Chapter ---> 6
# Arabic   :   كتاب الحيض
# Urdu   :   حیض کے احکام و مسائل
# English   :   Menstrual Periods
#
# Chapter ---> 7
# Arabic   :   كتاب التيمم
# Urdu   :   تیمم کے احکام و مسائل
# English   :   Rubbing hands and feet with dust (Tayammum)
#
# Chapter ---> 8
# Arabic   :   كتاب الصلاة
# Urdu   :   نماز کے احکام و مسائل
# English   :   Prayers (Salat)
#
# Chapter ---> 9
# Arabic   :   كتاب مواقيت الصلاة
# Urdu   :   اوقات نماز کے بیان میں
# English   :   Times of the Prayers
#
# Chapter ---> 10
# Arabic   :   كتاب الأذان
# Urdu   :   اذان کے مسائل کے بیان میں
# English   :   Call to Prayers (Adhaan)
#
# Chapter ---> 11
# Arabic   :   كتاب الأذان (صفة الصلوة)
# Urdu   :   اذان کے مسائل کے بیان میں (صفة الصلوة)
# English   :   Call to Prayers (Adhaan) (Sufa-Tu-Salat)
#
# Chapter ---> 12
# Arabic   :   كتاب الجمعة
# Urdu   :   جمعہ کے بیان میں
# English   :   Friday Prayer
#
# Chapter ---> 13
# Arabic   :   كتاب صلاة الخوف
# Urdu   :   نماز خوف کا بیان
# English   :   Fear Prayer
#
# Chapter ---> 14
# Arabic   :   كتاب العيدين
# Urdu   :   عیدین کے مسائل کے بیان میں
# English   :   The Two Festivals (Eids)
#
# Chapter ---> 15
# Arabic   :   كتاب الوتر
# Urdu   :   نماز وتر کے مسائل کا بیان
# English   :   Witr Prayer
#
# Chapter ---> 16
# Arabic   :   كتاب الاستسقاء
# Urdu   :   استسقاء یعنی پانی مانگنے کا بیان
# English   :   Invoking Allah for Rain (Istisqaa)
#
# Chapter ---> 17
# Arabic   :   كتاب الكسوف
# Urdu   :   سورج گہن کے متعلق بیان
# English   :   Eclipses
#
# Chapter ---> 18
# Arabic   :   كتاب سجود القرآن
# Urdu   :   سجود قرآن کے مسائل
# English   :   Prostration During Recital of Qur'an
#
# Chapter ---> 19
# Arabic   :   كتاب تقصير الصلاة
# Urdu   :   نماز میں قصر کرنے کا بیان
# English   :   Shortening the Prayers (At-Taqseer)
#
# Chapter ---> 20
# Arabic   :   كتاب التهجد
# Urdu   :   تہجد کا بیان
# English   :   Prayer at Night (Tahajjud)
#
# Chapter ---> 21
# Arabic   :   كتاب فضل الصلاة
# Urdu   :   مکہ و مدینہ میں نماز کی فضیلت
# English   :   Virtues of Prayer at Masjid Makkah and Madinah
#
# Chapter ---> 22
# Arabic   :   كتاب العمل في الصلاة
# Urdu   :   نماز کے کام کے بارے میں
# English   :   Actions while Praying
#
# Chapter ---> 23
# Arabic   :   كتاب السهو
# Urdu   :   سجدہ سھو کا بیان
# English   :   Forgetfulness in Prayer
#
# Chapter ---> 24
# Arabic   :   كتاب الجنائز
# Urdu   :   جنازے کے احکام و مسائل
# English   :   Funerals (Al-Janaa'iz)
#
# Chapter ---> 25
# Arabic   :   كتاب الزكاة
# Urdu   :   زکوۃ کے مسائل کا بیان
# English   :   Obligatory Charity Tax (Zakat)
#
# Chapter ---> 26
# Arabic   :   كتاب الحج
# Urdu   :   حج کے مسائل کا بیان
# English   :   Hajj (Pilgrimage)
#
# Chapter ---> 27
# Arabic   :   كتاب العمرة
# Urdu   :   عمرہ کے مسائل کا بیان
# English   :   `Umrah (Minor pilgrimage)
#
# Chapter ---> 28
# Arabic   :   كتاب المحصر
# Urdu   :   محرم کے روکے جانے اور شکار کا بدلہ دینے کے بیان میں
# English   :   Pilgrims Prevented from Completing the Pilgrimage
#
# Chapter ---> 29
# Arabic   :   كتاب جزاء الصيد
# Urdu   :   شکار کے بدلے کا بیان
# English   :   Penalty of Hunting while on Pilgrimage
#
# Chapter ---> 30
# Arabic   :   كتاب فضائل المدينة
# Urdu   :   مدینہ کے فضائل کا بیان
# English   :   Virtues of Madinah
#
# Chapter ---> 31
# Arabic   :   كتاب الصوم
# Urdu   :   روزے کے مسائل کا بیان
# English   :   Fasting
#
# Chapter ---> 32
# Arabic   :   كتاب صلاة التراويح
# Urdu   :   نماز تراویح پڑھنے کا بیان
# English   :   Praying at Night in Ramadaan (Taraweeh)
#
# Chapter ---> 33
# Arabic   :   كتاب فضل ليلة القدر
# Urdu   :   لیلۃ القدر کا بیان
# English   :   Virtues of the Night of Qadr
#
# Chapter ---> 34
# Arabic   :   كتاب الاعتكاف
# Urdu   :   اعتکاف کے مسائل کا بیان
# English   :   Retiring to a Mosque for Remembrance of Allah (I'tikaf)
#
# Chapter ---> 35
# Arabic   :   كتاب البيوع
# Urdu   :   خرید و فروخت کے مسائل کا بیان
# English   :   Sales and Trade
#
# Chapter ---> 36
# Arabic   :   كتاب السلم
# Urdu   :   بیع سلم کے بیان میں
# English   :   Sales in which a Price is paid for Goods to be Delivered Later (As-Salam)
#
# Chapter ---> 37
# Arabic   :   كتاب الشفعة
# Urdu   :   شفعہ کے بیان میں
# English   :   Shuf'a
#
# Chapter ---> 38
# Arabic   :   كتاب الإجارة
# Urdu   :   اجرت کے مسائل کا بیان
# English   :   Hiring
#
# Chapter ---> 39
# Arabic   :   كتاب الحوالات
# Urdu   :   حوالہ کے مسائل کا بیان
# English   :   Transferance of a Debt from One Person to Another (Al-Hawaala)
#
# Chapter ---> 40
# Arabic   :   كتاب الكفالة
# Urdu   :   کفالت کے مسائل کا بیان
# English   :   Kafalah
#
# Chapter ---> 41
# Arabic   :   كتاب الوكالة
# Urdu   :   وکالت کے مسائل کا بیان
# English   :   Representation, Authorization, Business by Proxy
#
# Chapter ---> 42
# Arabic   :   كتاب المزارعة
# Urdu   :   کھیتی باڑی اور بٹائی کا بیان
# English   :   Agriculture
#
# Chapter ---> 43
# Arabic   :   كتاب المساقاة
# Urdu   :   مساقات کے بیان میں
# English   :   Distribution of Water
#
# Chapter ---> 44
# Arabic   :   كتاب الاستقراض
# Urdu   :   قرض لینے ادا کرنے حجر اور مفلسی منظور کرنے کے بیان میں
# English   :   Loans, Payment of Loans, Freezing of Property, Bankruptcy
#
# Chapter ---> 45
# Arabic   :   كتاب الخصومات
# Urdu   :   نالشوں اور جھگڑوں کے بیان میں
# English   :   Khusoomaat
#
# Chapter ---> 46
# Arabic   :   كتاب اللقطة
# Urdu   :   لقطہ یعنی گری پڑی چیزوں کے بارے میں احکام
# English   :   Lost Things Picked up by Someone (Luqatah)
#
# Chapter ---> 47
# Arabic   :   کتاب المظالم والغصب
# Urdu   :   ظلم اور مال غصب کرنے کے بیان میں
# English   :   Oppressions
#
# Chapter ---> 48
# Arabic   :   كتاب الشركة
# Urdu   :   شراکت کے مسائل کے بیان میں
# English   :   Partnership
#
# Chapter ---> 49
# Arabic   :   كتاب الرهن
# Urdu   :   رہن کے بیان میں
# English   :   Mortgaging
#
# Chapter ---> 50
# Arabic   :   كتاب العتق
# Urdu   :   غلاموں کی آزادی کے بیان میں
# English   :   Manumission of Slaves
#
# Chapter ---> 51
# Arabic   :   كتاب المكاتب
# Urdu   :   مکاتب کے مسائل کا بیان
# English   :   Makaatib
#
# Chapter ---> 52
# Arabic   :   كتاب الهبة
# Urdu   :   ہبہ کےمسائل فضیلت اور ترغیب کا بیان
# English   :   Gifts
#
# Chapter ---> 53
# Arabic   :   كتاب الشهادات
# Urdu   :   گواہوں کے متعلق مسائل کا بیان
# English   :   Witnesses
#
# Chapter ---> 54
# Arabic   :   كتاب الصلح
# Urdu   :   صلح کے مسائل کا بیان
# English   :   Peacemaking
#
# Chapter ---> 55
# Arabic   :   كتاب الشروط
# Urdu   :   شرائط کے مسائل کا بیان
# English   :   Conditions
#
# Chapter ---> 56
# Arabic   :   كتاب الوصايا
# Urdu   :   وصیتوں کے مسائل کا بیان
# English   :   Wills and Testaments (Wasaayaa)
#
# Chapter ---> 57
# Arabic   :   كتاب الجهاد والسير
# Urdu   :   جہاد کا بیان
# English   :   Fighting for the Cause of Allah (Jihaad)
#
# Chapter ---> 58
# Arabic   :   كتاب فرض الخمس
# Urdu   :   خمس کے فرض ہونے کا بیان
# English   :   One-fifth of Booty to the Cause of Allah (Khumus)
#
# Chapter ---> 59
# Arabic   :   كتاب کتاب الجزیہ والموادعہ
# Urdu   :   جزیہ وغیرہ کے بیان میں
# English   :   Jizyah and Mawaada'ah
#
# Chapter ---> 60
# Arabic   :   كتاب بدء الخلق
# Urdu   :   اس بیان میں کہ مخلوق کی پیدائش کیونکر شروع ہوئی
# English   :   Beginning of Creation
#
# Chapter ---> 61
# Arabic   :   كتاب أحاديث الأنبياء
# Urdu   :   انبیاء علیہم السلام کے بیان میں
# English   :   Prophets
#
# Chapter ---> 62
# Arabic   :   كتاب المناقب
# Urdu   :   فضیلتوں کے بیان میں
# English   :   Virtues and Merits of the Prophet (PBUH) and his Companions
#
# Chapter ---> 63
# Arabic   :   كتاب فضائل الصحابة
# Urdu   :   نبی صلی اللہ علیہ وسلم کے اصحاب کی فضیلت
# English   :   Companions of the Prophet
#
# Chapter ---> 64
# Arabic   :   كتاب مناقب الأنصار
# Urdu   :   انصار کے مناقب
# English   :   Merits of the Helpers in Madinah (Ansaar)
#
# Chapter ---> 65
# Arabic   :   كتاب المغازي
# Urdu   :   غزوات کے بیان میں
# English   :   Military Expeditions led by the Prophet (PBUH) (Al-Maghaazi)
#
# Chapter ---> 66
# Arabic   :   كتاب التفسير
# Urdu   :   قرآن پاک کی تفسیر کے بیان میں
# English   :   Prophetic Commentary on the Qur'an (Tafseer of the Prophet (PBUH))
#
# Chapter ---> 67
# Arabic   :   كتاب فضائل القرآن
# Urdu   :   قرآن کے فضائل کا بیان
# English   :   Virtues of the Qur'an
#
# Chapter ---> 68
# Arabic   :   كتاب النكاح
# Urdu   :   نکاح کے مسائل کا بیان
# English   :   Wedlock, Marriage (Nikaah)
#
# Chapter ---> 69
# Arabic   :   كتاب الطلاق
# Urdu   :   طلاق کے مسائل کا بیان
# English   :   Divorce
#
# Chapter ---> 70
# Arabic   :   كتاب النفقات
# Urdu   :   خرچہ دینے کے بیان میں
# English   :   Supporting the Family
#
# Chapter ---> 71
# Arabic   :   كتاب الأطعمة
# Urdu   :   کھانوں کے بیان میں
# English   :   Food, Meals
#
# Chapter ---> 72
# Arabic   :   كتاب العقيقة
# Urdu   :   عقیقہ کے مسائل کا بیان
# English   :   Sacrifice on Occasion of Birth (`Aqiqa)
#
# Chapter ---> 73
# Arabic   :   كتاب الذبائح والصيد
# Urdu   :   ذبیح اور شکار کے بیان میں
# English   :   Hunting, Slaughtering
#
# Chapter ---> 74
# Arabic   :   كتاب الأضاحي
# Urdu   :   قربانی کے مسائل کا بیان
# English   :   Al-Adha Festival Sacrifice (Adaahi)
#
# Chapter ---> 75
# Arabic   :   كتاب الأشربة
# Urdu   :   مشروبات کے بیان میں
# English   :   Drinks
#
# Chapter ---> 76
# Arabic   :   كتاب المرضى
# Urdu   :   امراض اور ان کے علاج کے بیان میں
# English   :   Patients
#
# Chapter ---> 77
# Arabic   :   كتاب الطب
# Urdu   :   دوا اور علاج کے بیان میں
# English   :   Medicine
#
# Chapter ---> 78
# Arabic   :   كتاب اللباس
# Urdu   :   لباس کے بیان میں
# English   :   Dress
#
# Chapter ---> 79
# Arabic   :   كتاب الأدب
# Urdu   :   اخلاق کے بیان میں
# English   :   Good Manners and Form (Al-Adab)
#
# Chapter ---> 80
# Arabic   :   كتاب الاستئذان
# Urdu   :   اجازت لینے کے بیان میں
# English   :   Asking Permission
#
# Chapter ---> 81
# Arabic   :   كتاب الدعوات
# Urdu   :   دعاؤں کے بیان میں
# English   :   Invocations
#
# Chapter ---> 82
# Arabic   :   كتاب الرقاق
# Urdu   :   دل کو نرم کرنے والی باتوں کے بیان میں
# English   :   To make the Heart Tender (Ar-Riqaq)
#
# Chapter ---> 83
# Arabic   :   كتاب القدر
# Urdu   :   تقدیر کے بیان میں
# English   :   Divine Will (Al-Qadar)
#
# Chapter ---> 84
# Arabic   :   كتاب الأيمان والنذور
# Urdu   :   قسموں اور نذروں کے بیان میں
# English   :   Oaths and Vows
#
# Chapter ---> 85
# Arabic   :   كتاب كفارات الأيمان
# Urdu   :   قسموں کے کفارہ کے بیان میں
# English   :   Expiation for Unfulfilled Oaths
#
# Chapter ---> 86
# Arabic   :   كتاب الفرائض
# Urdu   :   فرائض یعنی ترکہ کے حصوں کے بیان میں
# English   :   Laws of Inheritance (Al-Faraa'id)
#
# Chapter ---> 87
# Arabic   :   كتاب الحدود
# Urdu   :   حد اور سزاؤں کے بیان میں
# English   :   Limits and Punishments set by Allah (Hudood)
#
# Chapter ---> 88
# Arabic   :   كتاب المحاربين
# Urdu   :   ان کفار و مرتدوں کے احکام میں جو مسلمانوں سے لڑتے ہیں
# English   :   Al-Maharbeen
#
# Chapter ---> 89
# Arabic   :   كتاب الديات
# Urdu   :   دیتوں کے بیان میں
# English   :   Blood Money (Ad-Diyat)
#
# Chapter ---> 90
# Arabic   :   كتاب استتابة المرتدين
# Urdu   :   باغیوں اور مرتدوں سے توبہ کرانے کا بیان
# English   :   Apostates
#
# Chapter ---> 91
# Arabic   :   كتاب الإكراه
# Urdu   :   زبردستی کام کرانے کے بیان میں
# English   :   (Statements made under) Coercion
#
# Chapter ---> 92
# Arabic   :   كتاب الحيل
# Urdu   :   شرعی حیلوں کے بیان میں
# English   :   Tricks
#
# Chapter ---> 93
# Arabic   :   كتاب التعبير
# Urdu   :   خوابوں کی تعبیر کے بیان میں
# English   :   Interpretation of Dreams
#
# Chapter ---> 94
# Arabic   :   كتاب الفتن
# Urdu   :   فتنوں کے بیان میں
# English   :   Afflictions and the End of the World
#
# Chapter ---> 95
# Arabic   :   كتاب الأحكام
# Urdu   :   حکومت اور قضا کے بیان میں
# English   :   Judgments (Ahkaam)
#
# Chapter ---> 96
# Arabic   :   كتاب التمني
# Urdu   :   نیک ترین آرزؤں کے جائز ہونے کے بیان میں
# English   :   Wishes
#
# Chapter ---> 97
# Arabic   :   كتاب أخبار الآحاد
# Urdu   :   خبر واحد کے بیان میں
# English   :   Accepting Information Given by a Truthful Person
#
# Chapter ---> 98
# Arabic   :   كتاب الاعتصام بال والسنة
# Urdu   :   اللہ اور سنت رسول اللہ صلی اللہ علیہ وسلم کو مضبوطی سے تھامے رہنا
# English   :   Holding Fast to the Qur'an and Sunnah
#
# Chapter ---> 99
# Arabic   :   كتاب التوحيد
# Urdu   :   اللہ کی توحید اس کی ذات اور صفات کے بیان میں
# English   :   Oneness, Uniqueness of Allah (Tawheed)
#
# Total Chapters Found: 99

# %%
import json
import pandas as pd

file_path = "/content/2_Sahih_Bukhari_sorted.json"

try:
    df = pd.DataFrame(json.load(open(file_path, 'r', encoding='utf-8')))
except:
    data = [json.loads(line) for line in open(file_path, 'r', encoding='utf-8') if line.strip()]
    df = pd.DataFrame(data)

print("Dataset Overview\n")
print(f"Total Books: {df['book'].nunique()}")
print(f"Total Hadiths: {len(df)}")
print(f"Total Chapters: {df['chapter_id'].nunique()}")

print("\nData Quality Checks")

nulls = df.isnull().sum()

if nulls.sum() == 0:
    print(f"\nMissing values: 0")
else:
    print(f"\n---> Missing values found:\n")
    for col in nulls[nulls>0].index:
        missing_ids = df[df[col].isnull()]['doc_id'].tolist()
        print(f"  {col}: {len(missing_ids)} -> {missing_ids}")

for col in ['arabic_text', 'urdu_text', 'english_text']:
    empty = df[col].isnull().sum() | (df[col].fillna('').str.strip()=='').sum()
    if empty == 0:
        print(f"\nEmpty {col}: 0")
    else:
        empty_ids = df[(df[col].isnull()) | (df[col].str.strip()=='')]['doc_id'].tolist()
        print(f"\nEmpty {col}: {empty} -> {empty_ids}")

print(f"\nDuplicate IDs: {df['doc_id'].duplicated().sum()}" if not df['doc_id'].duplicated().any() else f"---> Duplicates found")
# Out:
# Dataset Overview
#
# Total Books: 1
# Total Hadiths: 7276
# Total Chapters: 99
#
# Data Quality Checks
#
# ---> Missing values found:
#
#   english_text: 2 -> ['H_Bukhari_1830', 'H_Bukhari_6119']
#   narrator: 13 -> ['H_Bukhari_537', 'H_Bukhari_583', 'H_Bukhari_656', 'H_Bukhari_850', 'H_Bukhari_897', 'H_Bukhari_1250', 'H_Bukhari_1259', 'H_Bukhari_1324', 'H_Bukhari_1646', 'H_Bukhari_1848', 'H_Bukhari_2124', 'H_Bukhari_2173', 'H_Bukhari_4080']
#
# Empty arabic_text: 0
#
# Empty urdu_text: 0
#
# Empty english_text: 2 -> ['H_Bukhari_1830', 'H_Bukhari_6119']
#
# Duplicate IDs: 0

# %% [markdown]
# **2.3 - Hadith Dataset Refining**

# %%
import json
import pandas as pd

file_path = "/content/2_Sahih_Bukhari_sorted.json"

try:
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
except:
    data = [json.loads(line) for line in open(file_path, 'r', encoding='utf-8') if line.strip()]

print("Fixing missing data...")

for item in data:
    if item['doc_id'] == 'H_Bukhari_1830':
        item['english_text'] = 'While we were in the company of the Prophet (ﷺ) in a cave at Mina, when Surat-wal-Mursalat were revealed and he recited it and I heard it (directly) from his mouth as soon as he recited its revelation. Suddenly a snake sprang at us and the Prophet (ﷺ) said (ordered us): "Kill it." We ran to kill it but it escaped quickly. The Prophet (ﷺ) said, "It has escaped your evil and you too have escaped its evil."'
        print(f"\nFixed: {item['doc_id']} - Added English text")

    if item['doc_id'] == 'H_Bukhari_6119':
        item['english_text'] = 'The Prophet (ﷺ) was more shy (from Haya\': pious shyness from committing religeous indiscretions) than a veiled virgin girl.'
        print(f"\nFixed: {item['doc_id']} - Added English text")

    if item.get('narrator') is None or item.get('narrator') == '':
        item['narrator'] = 'Unknown'
        print(f"\nFixed: {item['doc_id']} - Added narrator as 'Unknown'")

output_file = file_path.replace('.json', '_fixed.json')
with open(output_file, 'w', encoding = 'utf-8') as f:
    json.dump(data, f, ensure_ascii = False, indent=2)

print(f"\nFixed dataset saved to: {output_file}")

df = pd.DataFrame(data)
print(f"\nVerification:")
print(f"Missing english_text: {df['english_text'].isnull().sum()}")
print(f"Missing narrator: {df['narrator'].isnull().sum()}")
# Out:
# Fixing missing data...
#
# Fixed: H_Bukhari_537 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_583 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_656 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_850 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_897 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_1250 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_1259 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_1324 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_1646 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_1830 - Added English text
#
# Fixed: H_Bukhari_1848 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_2124 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_2173 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_4080 - Added narrator as 'Unknown'
#
# Fixed: H_Bukhari_6119 - Added English text
#
# Fixed dataset saved to: /content/Sahih_Bukhari_sorted_fixed.json
#
# Verification:
# Missing english_text: 0
# Missing narrator: 0

# %%
import json

INPUT_FILE = "/content/3_Sahih_Bukhari_sorted_fixed.json"
OUTPUT_FILE = "4_Sahih_Bukhari_sorted_fixed_final.json"

with open(INPUT_FILE, "r", encoding="utf-8") as f:
    data = json.load(f)

expanded = []

for item in data:

    raw = str(item.get("hadith_id")).strip()

    if raw.isdigit():
        hid = int(raw)
        item["hadith_id"] = hid
        item["doc_id"] = f"H_Bukhari_{hid}"
        expanded.append(item)
        continue

    if "," in raw:
        parts = [p.strip() for p in raw.split(",")]

        for p in parts:
            if p.isdigit():
                hid = int(p)
                new_item = item.copy()
                new_item["hadith_id"] = hid
                new_item["doc_id"] = f"H_Bukhari_{hid}"
                expanded.append(new_item)
        continue

    digits = "".join([c for c in raw if c.isdigit()])
    if digits.isdigit():
        hid = int(digits)
        item["hadith_id"] = hid
        item["doc_id"] = f"H_Bukhari_{hid}"
        expanded.append(item)
        continue

    continue

# sorting by official hadith number...
expanded_sorted = sorted(expanded, key=lambda x: x["hadith_id"])

# sssigning the bukhari_id = order (1 to last)
for idx, item in enumerate(expanded_sorted, start=1):
    item["bukhari_id"] = idx

    # delete original_id if present...
    if "original_id" in item:
        del item["original_id"]

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(expanded_sorted, f, ensure_ascii=False, indent=2)

print(f"Total final hadith: {len(expanded_sorted)}")
print("\nSaved to:", OUTPUT_FILE)
# Out:
# Total final hadith: 7582
#
# Saved to: Sahih_Bukhari_sorted_fixed_final.json
